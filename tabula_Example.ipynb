# %%
import tabula

pdf_path = "http://www.adcon.rn.gov.br/ACERVO/sesap/DOC/DOC000000000256248.PDF"

dfs = tabula.read_pdf(pdf_path, stream=True, pages="8")
print(len(dfs))
dfs
# Out:
# 2
# [         Unnamed: 0 CASOS SUSPEITOS   Unnamed: 1 CASOS CONFIRMADOS  \
#  0   REGIÃO DE SAÚDE             NaN        CASOS               NaN
#  1               NaN             NaN          NaN               NaN
#  2     DE RESIDÊNCIA         TAXA DE  DESCARTADOS               NaN
#  3               NaN       SUSPEITOS          NaN    INCIDÊNCIA POR
#  4               NaN               N          NaN                 N
#  5               NaN     POR 100.000          NaN       100.000 HAB
#  6               NaN             HAB          NaN               NaN
#  7         1a REGIÃO     4888 1267,8        33884      18122 4700,2
#  8         2a REGIÃO      4372 893,2        68508      32375 6613,9
#  9         3a REGIÃO     4371 1201,4        26140      13590 3735,4
#  10        4a REGIÃO     8197 2733,6        47729      25682 8564,7
#  11        5a REGIÃO     2230 1108,0        22717       9668 4803,8
#  12        6a REGIÃO     3226 1282,1        42868      17597 6993,5
# ...
