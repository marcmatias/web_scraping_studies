# %%
import tabula

pdf_path = "https://coronavirus.saude.mg.gov.br/images/1_2021/01-boletim/13.04.21BOLETIMCOVID-19.pdf"

dfs = tabula.read_pdf(pdf_path, stream=True, pages="5")
print(len(dfs))
dfs[0]
# Out:
# Got stderr: May 06, 2021 1:51:47 PM org.apache.fontbox.ttf.CmapSubtable processSubtype4
# WARNING: cmap format 4 subtable is empty
# May 06, 2021 1:51:47 PM org.apache.fontbox.ttf.CmapSubtable processSubtype4
# WARNING: cmap format 4 subtable is empty
# May 06, 2021 1:51:47 PM org.apache.fontbox.ttf.CmapSubtable processSubtype4
# WARNING: cmap format 4 subtable is empty
# May 06, 2021 1:51:47 PM org.apache.fontbox.ttf.CmapSubtable processSubtype4
# WARNING: cmap format 4 subtable is empty
# May 06, 2021 1:51:47 PM org.apache.fontbox.ttf.CmapSubtable processSubtype4
# WARNING: cmap format 4 subtable is empty
# May 06, 2021 1:51:48 PM org.apache.fontbox.ttf.CmapSubtable processSubtype4
# WARNING: cmap format 4 subtable is empty
# May 06, 2021 1:51:48 PM org.apache.fontbox.ttf.CmapSubtable processSubtype4
# WARNING: cmap format 4 subtable is empty
# May 06, 2021 1:51:48 PM org.apache.fontbox.ttf.CmapSubtable processSubtype4
# WARNING: cmap format 4 subtable is empty
# ...
