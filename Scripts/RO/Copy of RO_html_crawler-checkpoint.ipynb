# %%
import pandas as pd
import numpy as np
import unidecode

from datetime import date, datetime, timedelta

import funcoes_eda as ufm

# %% [markdown]
# ## Crawler RO
#
# #### [Link para TESTE RO: 21/05/2021](http://www.rondonia.ro.gov.br/edicao-427-boletim-diario-sobre-coronavirus-em-rondonia/)

# %%
today = date.today() 
yesterday = today - timedelta(days=1)
print(f"today: {today}")
print(f"yesterday: {yesterday}")

now = str((datetime.now().strftime('%Y%m%d%H%M')))
print(f"now: {now}")

str_date = str((today.strftime('%d-%m-%Y')))
# str_date = str((today.strftime('%d-%m-%Y')))
# str_date = "20210406"
print(f"str_date: {str_date}")

path_date = str((today.strftime('%Y/%m')))
print(f"path_date: {path_date}")

uf = 'RO'
print(f"state: {uf}")

capital = 'Porto Velho'
print(f"capital: {capital}\n")
# Out:
# today: 2021-05-21
# yesterday: 2021-05-20
# now: 202105212144
# str_date: 21-05-2021
# path_date: 2021/05
# state: RO
# capital: Porto Velho

# %%
# define url de origem do boletim
pdf_link = f'http://www.rondonia.ro.gov.br/edicao-427-boletim-diario-sobre-coronavirus-em-rondonia/f'
print(f"URL do boletim: {pdf_link}\n")
# Out:
# URL do boletim: http://www.rondonia.ro.gov.br/edicao-427-boletim-diario-sobre-coronavirus-em-rondonia/f

# %%
# carrega pdf e transforma tabela(s)
tables = camelot.read_pdf(pdf_link, pages='6')
print(tables, len(tables))

for i in range(len(tables)):
    print(tables[i].parsing_report)

# # exibe todas as tabelas encontradas nas páginas pesquisadas
# for i in range(len(tables)):
#     print(f"\nTabela {i+1}:")
#     display(tables[i].df)
# Out:
# URL do boletim: https://agencia.ac.gov.br/wp-content/uploads/2021/05/BOLETIM_AC_COVID_21-05-2021-1.pdf
#
# <TableList n=1> 1
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 6}

# %%
df_ac = tables[0].df.copy()
df_ac.columns = df_ac.iloc[0]
df_ac.drop(df_ac.index[0], inplace=True)
df_ac.rename(columns=lambda x: unidecode.unidecode(x).strip().replace(" ", "_").replace("\n", "").replace("*", "").lower(), inplace=True)
df_ac.rename(columns={'municipios': 'municipio', 'casos_confirmados': 'confirmados', 'obitos': 'mortes'}, inplace=True)
# df_ac.rename(columns = {"casos_confirmados": "casos", "obitos": "mortes"}, inplace=True)
df_ac = df_ac[['municipio', 'confirmados', 'mortes']]
df_ac['confirmados'] = df_ac['confirmados'].str.replace(".", "").astype(int)
df_ac['mortes'] = df_ac['mortes'].str.replace(".", "").astype(int)
ufm.check_null(df_ac)
df_ac
# Out:
# Não existem colunas com valores ausentes
# 0             municipio  confirmados  mortes
# 1            Acrelândia         1538      32
# 2          Assis Brasil         1597      22
# 3             Brasileia         2676      36
# 4                Bujari         1108      15
# 5              Capixaba          620      17
# 6       Cruzeiro do Sul         7406     149
# 7        Epitaciolândia         1331      28
# 8                 Feijó         2991      59
# 9                Jordão          397       1
# 10          Mâncio Lima         2099      26
# 11        Manoel Urbano          895      12
# 12       M. Thaumaturgo         1214       9
# 13    Plácido de Castro         1549      16
# 14           Porto Acre         1385      33
# 15         Porto Walter          532       3
# 16           Rio Branco        36152     990
# 17      Rodrigues Alves          775      11
# 18  Santa Rosa do Purus          899       7
# 19       Sena Madureira         5641      63
# 20     Senador Guiomard         1122      41
# 21             Tarauacá         6375      35
# 22               Xapuri         2933      27
# 23                TOTAL        81235    1632

# %%
# ufm.municipios_brio(uf)

# %%
df = df_ac.copy()
display(df.query("municipio == @capital"))

df = df[df.municipio != "TOTAL"] 

print(f"\nsoma confirmados: {df.confirmados.sum()}\nsoma mortes: {df.mortes.sum()}")
# df = df.replace({'Ignorado':'Importados/Indefinidos', 'Total': 'TOTAL NO ESTADO'})
df = df.groupby(['municipio'], as_index=False).sum()
df['municipio'] = df['municipio'].str.replace('M. Thaumaturgo', 'Marechal Thaumaturgo')
df['municipio'] = ufm.normaliza_txt_upper(df['municipio'])
display(df.query("municipio == @capital.upper()"))

df = pd.merge(ufm.municipios_brio(uf), df, on=['municipio'], how='outer')

print(f"\nCONFLITOS DE GRAFIA DE MUNICÍPIO:\n\n{df[df['city'].isnull()]}" if df['city'].isnull().any() else "\nNENHUM CONFLITOS DE GRAFIA DE MUNICÍPIO!")

df.drop(columns=['municipio'], inplace=True)
df.rename(columns={'city': 'municipio'}, inplace=True)

df.at[0, 'confirmados'] = df.confirmados.sum()
df.at[0, 'mortes'] = df.mortes.sum()

# df.query("confirmados != 0 & mortes != 0")
df[['confirmados', 'mortes']] = df[['confirmados', 'mortes']].astype("Int64")

print(f"\n{df.shape[0]} linhas e {df.shape[1]} colunas.\n")
ufm.check_null(df)

# só usar se for mesmo para preencher com zero neste estado
df = df.fillna(0)

# # SALVA ARQUIVO
# now = str((datetime.now().strftime('%Y%m%d%H%M')))
# filename = f'caso-{uf}-{str_date}_csv_ses.csv' 
# df.to_csv(filename, index=False)
# print(f"\nArquivo salvo: {filename}")

display(df)
# Out:
# 0    municipio  confirmados  mortes
# 16  Rio Branco        36152     990
# soma confirmados: 81235
# soma mortes: 1632
# 0    municipio  confirmados  mortes
# 15  RIO BRANCO        36152     990
# NENHUM CONFLITOS DE GRAFIA DE MUNICÍPIO!
#
# 24 linhas e 3 colunas.
#
# Valores ausentes de confirmados: 1
# Valores ausentes de mortes: 1
#
# Arquivo salvo: caso-AC-21-05-2021_csv_ses.csv
#                  municipio  confirmados  mortes
# 0          TOTAL NO ESTADO        81235    1632
# 1   Importados/Indefinidos            0       0
# 2               Acrelândia         1538      32
# 3             Assis Brasil         1597      22
# 4                Brasiléia         2676      36
# 5                   Bujari         1108      15
# 6                 Capixaba          620      17
# 7          Cruzeiro do Sul         7406     149
# 8           Epitaciolândia         1331      28
# 9                    Feijó         2991      59
# 10                  Jordão          397       1
# 11             Mâncio Lima         2099      26
# 12           Manoel Urbano          895      12
# 13    Marechal Thaumaturgo         1214       9
# 14       Plácido de Castro         1549      16
# 15              Porto Acre         1385      33
# 16            Porto Walter          532       3
# 17              Rio Branco        36152     990
# 18         Rodrigues Alves          775      11
# 19     Santa Rosa do Purus          899       7
# 20          Sena Madureira         5641      63
# 21        Senador Guiomard         1122      41
# 22                Tarauacá         6375      35
# 23                  Xapuri         2933      27
