# %%
import tabula
# pdf_path = "https://github.com/chezou/tabula-py/raw/master/tests/resources/data.pdf"
pdf_path = "20210520_TO.pdf"

dfs = tabula.io.read_pdf(pdf_path, pages="2-4", stream=True)
# read_pdf returns list of DataFrames
print(len(dfs))
display(
    
dfs[0]
)
display(
    
dfs[1]
)
display(
    
dfs[2]
)
display(
    
dfs[3]
)
display(
    
dfs[4]
)
# Out:
# 4
#                                  0 a 9 anos 47  Unnamed: 0  \
# 0                              10 a 19 anos 81         NaN
# 1                             20 a 39 anos 354         NaN
# 2  40 a 59 anos Feminino41460 a 69 anos 269 61       443.0
# 3                                          NaN         NaN
# 4                                     70 e+ 45         NaN
# 5                                    TOTAL 857         NaN
#
#                       Unnamed: 1
# 0                            NaN
# 1                      Masculino
# 2                            NaN
# 3  Fonte:  Centro de Informações
# 4  Estratégicas da Vigilância em
# 5               Saúde – CIEVS/TO
#     Unnamed: 0                 MUNICÍPIO    TOTAL  Unnamed: 1  \
# 0            1                    PALMAS   40.859          41
# 1            2                 ARAGUAÍNA   29.128          42
# 2            3                    GURUPI   10.306          43
# ...
